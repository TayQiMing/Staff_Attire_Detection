# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/staff-attire-detect-sample-video/kaggle_50ep_model.pt
# /kaggle/input/staff-attire-detect-sample-video/sample.mp4
# /kaggle/input/staff-attire-detect-sample-video/kaggle_100ep_model.pt

# %%
# !nvidia-smi
# Out:
# Sun Oct 29 09:52:46 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

import os
from ultralytics import YOLO
from IPython.display import display, Image

HOME = os.getcwd()
print(HOME)

# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# Download the dataset version based on your modification 
# Simlpy choose the dataset you want and export with generated code as below
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("qi-ming").project("staff-attire-identification")
dataset = project.version(4).download("yolov8")
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5016.7/8062.4 GB disk)
# /kaggle/working
# /kaggle/working/datasets
# Collecting roboflow
#   Downloading roboflow-1.1.7-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.4 MB/s eta 0:00:00
# Collecting certifi==2022.12.7 (from roboflow)
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.3 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 18.9 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from roboflow) (3.7.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 27.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from roboflow) (9.5.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.16.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.26.15)
# Requirement already satisfied: tqdm>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (6.0)
# Requirement already satisfied: requests-toolbelt in /opt/conda/lib/python3.10/site-packages (from roboflow) (0.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (4.40.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (21.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->roboflow) (3.1.0)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from supervision->roboflow) (1.11.2)
# Installing collected packages: pyparsing, opencv-python-headless, idna, cycler, chardet, certifi, supervision, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.76
#     Uninstalling opencv-python-headless-4.8.0.76:
#       Successfully uninstalled opencv-python-headless-4.8.0.76
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pytoolconfig 1.2.5 requires packaging>=22.0, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.2 which is incompatible.
# Successfully installed certifi-2022.12.7 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 roboflow-1.1.7 supervision-0.16.0
# A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.134`
# Downloading Dataset Version Zip in Staff-Attire-Identification-4 to yolov8:: 100%|██████████| 87780/87780 [00:01<00:00, 58455.96it/s]
# Extracting Dataset Version Zip to Staff-Attire-Identification-4 in yolov8:: 100%|██████████| 1668/1668 [00:00<00:00, 5585.76it/s]

# %% [markdown]
# ### Predict with model

# %% [markdown]
# - used for predict sample.mp4 video

# %%
video_path = "/kaggle/input/staff-attire-detect-sample-video/sample.mp4"
model_100ep_path = "/kaggle/input/staff-attire-detect-sample-video/kaggle_100ep_model.pt"
model_50ep_path = "/kaggle/input/staff-attire-detect-sample-video/kaggle_50ep_model.pt"

# %%
## If use command code, will not get result generator, only video output
# !yolo task=detect mode=predict model={model_50ep_path} conf=0.25 source={video_path} save=True

# %%
from ultralytics import YOLO
import pandas as pd

source = video_path
model_50ep = YOLO(model_50ep_path)
results1 = model_50ep(source, save=True)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# Results saved to runs/detect/predict

# %%
# save each box xy coordinate & width,height tensor record
temp = [i.boxes.xywh for i in results1]

# save in dataframe
model50ep_video_df = pd.DataFrame(columns=["detect_boxes_values", "detect_name_tag_count"])
model50ep_video_df.index.name = "video_frame"

for i in temp:
    detect_boxes = i.cpu().numpy()
    detect_boxes_count = detect_boxes.shape[0]
    boxes_values = detect_boxes if detect_boxes_count != 0 else '-'
    model50ep_video_df = pd.concat([model50ep_video_df, pd.DataFrame({"detect_boxes_values": [boxes_values], "detect_name_tag_count": [detect_boxes_count]})], ignore_index=True)

# %%
model50ep_video_df
# Out:
#      detect_boxes_values detect_name_tag_count
# 0                      -                     0
# 1                      -                     0
# 2                      -                     0
# 3                      -                     0
# 4                      -                     0
# ...                  ...                   ...
# 1336                   -                     0
# 1337                   -                     0
# 1338                   -                     0
# 1339                   -                     0
# 1340                   -                     0
#
# [1341 rows x 2 columns]

# %%
model50ep_video_df_detected = model50ep_video_df[model50ep_video_df.detect_name_tag_count>=1]
print(f"Total video frame: {len(model50ep_video_df)} Detected video frame: {len(model50ep_video_df_detected)} ")
# Out:
# Total video frame: 1341 Detected video frame: 293

# %%
for index, row in model50ep_video_df_detected.iterrows():
    boxes_values = row['detect_boxes_values']
    name_tag_count = row['detect_name_tag_count']
    print(f"Video frame {index+1}: Total detected nametag = {name_tag_count}, Boxes xywh = {boxes_values}")
# Out:
# Video frame 320: Total detected nametag = 1, Boxes xywh = [[       98.5       461.5           7          13]]
# Video frame 321: Total detected nametag = 1, Boxes xywh = [[        106         475           6          12]]
# Video frame 435: Total detected nametag = 1, Boxes xywh = [[      555.5         550          21          10]]
# Video frame 436: Total detected nametag = 1, Boxes xywh = [[      567.5         522          21          10]]
# Video frame 437: Total detected nametag = 1, Boxes xywh = [[        573       493.5          22          11]]
# Video frame 438: Total detected nametag = 1, Boxes xywh = [[        573       469.5          20           9]]
# Video frame 459: Total detected nametag = 1, Boxes xywh = [[      437.5        56.5          15           9]]
# Video frame 460: Total detected nametag = 1, Boxes xywh = [[      438.5        54.5          15           9]]
# Video frame 461: Total detected nametag = 1, Boxes xywh = [[        445        52.5          18           9]]
# Video frame 462: Total detected nametag = 1, Boxes xywh = [[        452        51.5          18           9]]
# Video frame 463: Total detected nametag = 1, Boxes xywh = [[        468        52.5          18           9]]
# Video frame 464: Total detected nametag = 1, Boxes xywh = [[        487        55.5          16           9]]
# Video frame 465: Total detected nametag = 1, Boxes xywh = [[        502        57.5          16           9]]
# Video frame 466: Total detected nametag = 1, Boxes xywh = [[        511        65.5          16           9]]
# Video frame 467: Total detected nametag = 1, Boxes xywh = [[        515          73          14           8]]
# Video frame 468: Total detected nametag = 1, Boxes xywh = [[        522        87.5          16           9]]
# Video frame 469: Total detected nametag = 1, Boxes xywh = [[        525        98.5          16           9]]
# Video frame 470: Total detected nametag = 1, Boxes xywh = [[        526       111.5          16           9]]
# Video frame 471: Total detected nametag = 1, Boxes xywh = [[      532.5       128.5          17           9]]
# Video frame 472: Total detected nametag = 1, Boxes xywh = [[      538.5         145          17          10]]
# Video frame 473: Total detected nametag = 1, Boxes xywh = [[      550.5       171.5          17          11]]
# Video frame 474: Total detected nametag = 1, Boxes xywh = [[      559.5         196          17          10]]
# Video frame 502: Total detected nametag = 1, Boxes xywh = [[      499.5         716          11           8]]
# Video frame 503: Total detected nametag = 1, Boxes xywh = [[        501         705          14           8]]
# Video frame 504: Total detected nametag = 1, Boxes xywh = [[        502       698.5          16           9]]
# Video frame 505: Total detected nametag = 1, Boxes xywh = [[      505.5       684.5          17           9]]
# Video frame 506: Total detected nametag = 1, Boxes xywh = [[      508.5         667          19          10]]
# Video frame 507: Total detected nametag = 1, Boxes xywh = [[        514         652          20          10]]
# Video frame 508: Total detected nametag = 1, Boxes xywh = [[        520         632          22          10]]
# Video frame 509: Total detected nametag = 1, Boxes xywh = [[      532.5         608          19          10]]
# Video frame 510: Total detected nametag = 1, Boxes xywh = [[      540.5         592          21          10]]
# Video frame 511: Total detected nametag = 1, Boxes xywh = [[      546.5         576          21          10]]
# Video frame 512: Total detected nametag = 1, Boxes xywh = [[        553         547          22          10]]
# Video frame 513: Total detected nametag = 1, Boxes xywh = [[      556.5       523.5          21          11]]
# Video frame 514: Total detected nametag = 1, Boxes xywh = [[        558         498          22          10]]
# Video frame 515: Total detected nametag = 1, Boxes xywh = [[      560.5         466          19          10]]
# Video frame 516: Total detected nametag = 1, Boxes xywh = [[      557.5       445.5          13           9]]
# Video frame 541: Total detected nametag = 1, Boxes xywh = [[      685.5        75.5           7           9]]
# Video frame 544: Total detected nametag = 1, Boxes xywh = [[        694        72.5           6          13]]
# Video frame 545: Total detected nametag = 1, Boxes xywh = [[      691.5        74.5           7          13]]
# Video frame 929: Total detected nametag = 1, Boxes xywh = [[        451          56          16          10]]
# Video frame 930: Total detected nametag = 1, Boxes xywh = [[        469        56.5          18           9]]
# Video frame 931: Total detected nametag = 1, Boxes xywh = [[        483        55.5          16           9]]
# Video frame 932: Total detected nametag = 1, Boxes xywh = [[      496.5          57          15          10]]
# Video frame 933: Total detected nametag = 1, Boxes xywh = [[        507        64.5          14           9]]
# Video frame 934: Total detected nametag = 1, Boxes xywh = [[        513        72.5          14           9]]
# Video frame 935: Total detected nametag = 1, Boxes xywh = [[        519          82          14          10]]
# Video frame 936: Total detected nametag = 1, Boxes xywh = [[        528          95          16          12]]
# Video frame 937: Total detected nametag = 1, Boxes xywh = [[      531.5       105.5          17          11]]
# Video frame 938: Total detected nametag = 1, Boxes xywh = [[        539       124.5          18          13]]
# Video frame 939: Total detected nametag = 1, Boxes xywh = [[      548.5       148.5          19          13]]
# Video frame 940: Total detected nametag = 1, Boxes xywh = [[        560         171          20          14]]
# Video frame 941: Total detected nametag = 1, Boxes xywh = [[      566.5       196.5          21          15]]
# Video frame 942: Total detected nametag = 1, Boxes xywh = [[      570.5       227.5          19          13]]
# Video frame 943: Total detected nametag = 1, Boxes xywh = [[      573.5         251          19          12]]
# Video frame 944: Total detected nametag = 1, Boxes xywh = [[        575         285          18          10]]
# Video frame 968: Total detected nametag = 1, Boxes xywh = [[        492         715          12          10]]
# Video frame 969: Total detected nametag = 1, Boxes xywh = [[      491.5       707.5          17          11]]
# Video frame 970: Total detected nametag = 1, Boxes xywh = [[      490.5         700          17          10]]
# Video frame 971: Total detected nametag = 1, Boxes xywh = [[        488       691.5          16           9]]
# Video frame 972: Total detected nametag = 1, Boxes xywh = [[      485.5       680.5          17           9]]
# Video frame 973: Total detected nametag = 1, Boxes xywh = [[      486.5       670.5          17          11]]
# Video frame 974: Total detected nametag = 1, Boxes xywh = [[      488.5         662          17          12]]
# Video frame 975: Total detected nametag = 1, Boxes xywh = [[      491.5       652.5          19          11]]
# Video frame 976: Total detected nametag = 1, Boxes xywh = [[        498       634.5          20          13]]
# Video frame 977: Total detected nametag = 1, Boxes xywh = [[      502.5         623          21          14]]
# Video frame 978: Total detected nametag = 1, Boxes xywh = [[      510.5         607          21          14]]
# Video frame 979: Total detected nametag = 1, Boxes xywh = [[        518         588          22          16]]
# Video frame 980: Total detected nametag = 1, Boxes xywh = [[        523         570          22          16]]
# Video frame 981: Total detected nametag = 1, Boxes xywh = [[        533       539.5          22          15]]
# Video frame 982: Total detected nametag = 1, Boxes xywh = [[      540.5         521          23          16]]
# Video frame 983: Total detected nametag = 1, Boxes xywh = [[        549         492          24          18]]
# Video frame 984: Total detected nametag = 1, Boxes xywh = [[        555       470.5          24          17]]
# Video frame 985: Total detected nametag = 1, Boxes xywh = [[      569.5       437.5          21          13]]
# Video frame 986: Total detected nametag = 1, Boxes xywh = [[        579         408          20          12]]
# Video frame 1012: Total detected nametag = 1, Boxes xywh = [[      523.5        29.5          15          13]]
# Video frame 1013: Total detected nametag = 1, Boxes xywh = [[      532.5          34          17          12]]
# Video frame 1014: Total detected nametag = 1, Boxes xywh = [[      537.5        39.5          17          13]]
# Video frame 1170: Total detected nametag = 1, Boxes xywh = [[        553       434.5          24          15]]
# Video frame 1171: Total detected nametag = 1, Boxes xywh = [[        560         413          20          14]]
# Video frame 1172: Total detected nametag = 1, Boxes xywh = [[      563.5       383.5          21          13]]
# Video frame 1197: Total detected nametag = 1, Boxes xywh = [[      526.5          40          19          16]]
# Video frame 1198: Total detected nametag = 1, Boxes xywh = [[      533.5          44          21          16]]
# Video frame 1199: Total detected nametag = 1, Boxes xywh = [[      544.5          53          23          16]]
# Video frame 1200: Total detected nametag = 2, Boxes xywh = [[        552          60          22          16]
#  [      706.5         144           9          12]]
# Video frame 1201: Total detected nametag = 1, Boxes xywh = [[      553.5          66          23          16]]
# Video frame 1202: Total detected nametag = 1, Boxes xywh = [[        553          79          20          16]]
# Video frame 1203: Total detected nametag = 1, Boxes xywh = [[        552        89.5          22          17]]
# Video frame 1204: Total detected nametag = 1, Boxes xywh = [[      549.5       102.5          23          17]]
# Video frame 1205: Total detected nametag = 1, Boxes xywh = [[      549.5       112.5          25          17]]
# Video frame 1206: Total detected nametag = 1, Boxes xywh = [[      552.5         132          25          18]]
# Video frame 1207: Total detected nametag = 1, Boxes xywh = [[        558         156          22          16]]
# Video frame 1208: Total detected nametag = 1, Boxes xywh = [[      565.5       173.5          25          17]]
# Video frame 1209: Total detected nametag = 1, Boxes xywh = [[      572.5       198.5          25          17]]
# Video frame 1210: Total detected nametag = 1, Boxes xywh = [[      574.5       216.5          23          15]]
# Video frame 1211: Total detected nametag = 1, Boxes xywh = [[      579.5         251          13          12]]
# Video frame 1236: Total detected nametag = 1, Boxes xywh = [[      493.5       705.5          13           9]]
# Video frame 1237: Total detected nametag = 1, Boxes xywh = [[        495       703.5          14           9]]
# Video frame 1238: Total detected nametag = 1, Boxes xywh = [[      498.5         697          11          10]]
# Video frame 1239: Total detected nametag = 1, Boxes xywh = [[      502.5         692          15          12]]
# Video frame 1240: Total detected nametag = 1, Boxes xywh = [[      503.5       684.5          13          11]]
# Video frame 1241: Total detected nametag = 1, Boxes xywh = [[      501.5       678.5          13          11]]
# Video frame 1242: Total detected nametag = 1, Boxes xywh = [[      493.5       665.5          13           9]]
# Video frame 1243: Total detected nametag = 1, Boxes xywh = [[      485.5       658.5          11           9]]
# Video frame 1244: Total detected nametag = 1, Boxes xywh = [[      477.5       649.5          13           9]]

# %%
# Save the result to csv file
model50ep_video_df.to_csv('/kaggle/working/50epoch_video_total_output.csv', index=True)
model50ep_video_df_detected.to_csv('/kaggle/working/50epoch_video_detected_output.csv', index=True)

# %% [markdown]
# ### Deploy model to roboflow

# %%
# !mkdir /kaggle/working/temp
# !mkdir /kaggle/working/temp/weights

# %%
# !cp /kaggle/input/staff-attire-detect-sample-video/kaggle_50ep_model.pt /kaggle/working/temp/weights/best.pt

# %%
## Deploy with kaggle notebook
# project.version(dataset.version).deploy(model_type="yolov8", model_path=f"/kaggle/working/temp/")

# %% [markdown]
# View the status of your deployment at: https://app.roboflow.com/qi-ming/staff-attire-identification/4
# <br>
# Share your model with the world at: https://universe.roboflow.com/qi-ming/staff-attire-identification/model/4

# %%
# # Created output zip file
# !zip -r staff_attire_detect_output.zip /kaggle/working/
